# %%
import pandas as pd
import numpy as np

import scipy.stats as stats
import matplotlib.pyplot as plt 
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from sklearn.model_selection import cross_val_score

from sklearn.linear_model import LinearRegression

from sklearn.preprocessing import PowerTransformer

# %%
df = pd.read_csv('concrete_data.csv')

# %%
df.head()
# Out:
#    Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
# 3   332.5               142.5      0.0  228.0               0.0
# 4   198.6               132.4      0.0  192.0               0.0
#
#    Coarse Aggregate  Fine Aggregate  Age  Strength
# 0            1040.0           676.0   28     79.99
# 1            1055.0           676.0   28     61.89
# 2             932.0           594.0  270     40.27
# 3             932.0           594.0  365     41.05
# 4             978.4           825.5  360     44.30

# %%
df.shape
# Out:
# (1030, 9)

# %%
df.isnull().sum()
# Out:
# Cement                0
# Blast Furnace Slag    0
# Fly Ash               0
# Water                 0
# Superplasticizer      0
# Coarse Aggregate      0
# Fine Aggregate        0
# Age                   0
# Strength              0
# dtype: int64

# %%
df.describe()
# Out:
#             Cement  Blast Furnace Slag      Fly Ash        Water  \
# count  1030.000000         1030.000000  1030.000000  1030.000000
# mean    281.167864           73.895825    54.188350   181.567282
# std     104.506364           86.279342    63.997004    21.354219
# min     102.000000            0.000000     0.000000   121.800000
# 25%     192.375000            0.000000     0.000000   164.900000
# 50%     272.900000           22.000000     0.000000   185.000000
# 75%     350.000000          142.950000   118.300000   192.000000
# max     540.000000          359.400000   200.100000   247.000000
#
#        Superplasticizer  Coarse Aggregate  Fine Aggregate          Age  \
# count       1030.000000       1030.000000     1030.000000  1030.000000
# mean           6.204660        972.918932      773.580485    45.662136
# std            5.973841         77.753954       80.175980    63.169912
# min            0.000000        801.000000      594.000000     1.000000
# ...

# %%
x = df.drop(columns=['Strength'])
y= df.iloc[:,-1]

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=1)

# %%
lr = LinearRegression()

lr.fit(X_train,y_train)

y_pred = lr.predict(X_test)

r2_score(y_test,y_pred)
# Out:
# 0.5210125654324629

# %%
lr = LinearRegression()

np.mean(cross_val_score(lr,x,y,scoring='r2'))
# Out:
# 0.4609940491662865

# %%
for col in X_train.columns:
    plt.figure(figsize=(14,4))
    plt.subplot(121)
    sns.distplot(X_train[col])
    plt.title(col)

    plt.subplot(122)
    stats.probplot(X_train[col],dist="norm",plot=plt)
    plt.title(col)

    plt.show()
# Out:
# /var/folders/sr/v_bsvj7j3lgg41xztlkdg5zh0000gn/T/ipykernel_86125/1516004789.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(X_train[col])
# /var/folders/sr/v_bsvj7j3lgg41xztlkdg5zh0000gn/T/ipykernel_86125/1516004789.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
pt = PowerTransformer(method='box-cox')

X_train_t = pt.fit_transform(X_train+0.000001)
X_test_t = pt.fit_transform(X_test+0.000001)

pd.DataFrame({'cols':X_train.columns,'box-cox-lambdas':pt.lambdas_})
# Out:
#                  cols  box-cox-lambdas
# 0              Cement         0.307096
# 1  Blast Furnace Slag         0.060141
# 2             Fly Ash        -0.031921
# 3               Water         0.469884
# 4    Superplasticizer         0.118322
# 5    Coarse Aggregate         0.644188
# 6      Fine Aggregate         1.565283
# 7                 Age         0.018145

# %%
lr = LinearRegression()

lr.fit(X_train_t,y_train)

y_pred = lr.predict(X_test_t)

r2_score(y_test,y_pred)
# Out:
# 0.750368616743228

# %%
pt = PowerTransformer(method='box-cox')

X_train_t = pt.fit_transform(x+0.000001)

lr = LinearRegression()

np.mean(cross_val_score(lr,X_train_t,y,scoring='r2'))
# Out:
# 0.6662950328464643

# %%
X_train_t2= pd.DataFrame(X_train_t,columns=X_train.columns)
for col in X_train.columns:
    plt.figure(figsize=(14,4))
    plt.subplot(121)
    sns.distplot(X_train[col])
    plt.title(col)

    plt.subplot(122)
    sns.distplot(X_train_t2[col])
    plt.title(col)

    plt.show()
# Out:
# /var/folders/sr/v_bsvj7j3lgg41xztlkdg5zh0000gn/T/ipykernel_86125/2698680955.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(X_train[col])
# /var/folders/sr/v_bsvj7j3lgg41xztlkdg5zh0000gn/T/ipykernel_86125/2698680955.py:9: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
pt1 = PowerTransformer()

X_train_t1 = pt1.fit_transform(X_train)
X_test_t1 = pt1.fit_transform(X_test)

lr1 = LinearRegression()

lr1.fit(X_train_t,y_train)

y_pred1 = lr1.predict(X_test_t)

print(r2_score(y_test,y_pred1))

pd.DataFrame({'cols':X_train.columns,'yeo-johnson-lambdas':pt1.lambdas_})
# Out:
# 0.7501115320152897
#                  cols  yeo-johnson-lambdas
# 0              Cement             0.305154
# 1  Blast Furnace Slag             0.121523
# 2             Fly Ash            -0.138992
# 3               Water             0.467114
# 4    Superplasticizer             0.298060
# 5    Coarse Aggregate             0.643896
# 6      Fine Aggregate             1.566141
# 7                 Age            -0.028973

# %%
pd.DataFrame({'cols':X_train.columns,'box-cox-lambdas':pt.lambdas_,'yeo-johnson-lambdas':pt1.lambdas_})
# Out:
#                  cols  box-cox-lambdas  yeo-johnson-lambdas
# 0              Cement         0.307096             0.305154
# 1  Blast Furnace Slag         0.060141             0.121523
# 2             Fly Ash        -0.031921            -0.138992
# 3               Water         0.469884             0.467114
# 4    Superplasticizer         0.118322             0.298060
# 5    Coarse Aggregate         0.644188             0.643896
# 6      Fine Aggregate         1.565283             1.566141
# 7                 Age         0.018145            -0.028973
