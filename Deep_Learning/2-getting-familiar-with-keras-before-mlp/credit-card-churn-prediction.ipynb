# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/credit-card-customer-churn-prediction/Churn_Modelling.csv

# %%
df = pd.read_csv('/kaggle/input/credit-card-customer-churn-prediction/Churn_Modelling.csv')

# %%
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0

# %%
df.shape
# Out:
# (10000, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df['Exited'].value_counts()
# Out:
# Exited
# 0    7963
# 1    2037
# Name: count, dtype: int64

# %%
df['Geography'].value_counts()
# Out:
# Geography
# France     5014
# Germany    2509
# Spain      2477
# Name: count, dtype: int64

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Male      5457
# Female    4543
# Name: count, dtype: int64

# %%
df.drop(columns=['RowNumber','CustomerId','Surname'],inplace=True)

# %%
df.head()
# Out:
#    CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619    France  Female   42       2       0.00              1
# 1          608     Spain  Female   41       1   83807.86              1
# 2          502    France  Female   42       8  159660.80              3
# 3          699    France  Female   39       1       0.00              2
# 4          850     Spain  Female   43       2  125510.82              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0          1               1        101348.88       1
# 1          0               1        112542.58       0
# 2          1               0        113931.57       1
# 3          0               0         93826.63       0
# 4          1               1         79084.10       0

# %%
df = pd.get_dummies(df ,columns=['Geography','Gender'],drop_first=True)

# %%
from sklearn.model_selection import train_test_split

# %%
x = df.drop(columns=['Exited'])
y= df['Exited']

# %%
x_train , x_test , y_train, y_test = train_test_split(x,y, test_size=0.2, random_state=1)

# %%
x_train.shape
# Out:
# (8000, 11)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler= StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %%
x_train
# Out:
# array([[-0.23082038, -0.94449979, -0.70174202, ...,  1.71490137,
#         -0.57273139,  0.91509065],
#        [-0.25150912, -0.94449979, -0.35520275, ..., -0.58312392,
#         -0.57273139, -1.09278791],
#        [-0.3963303 ,  0.77498705,  0.33787579, ...,  1.71490137,
#         -0.57273139, -1.09278791],
#        ...,
#        [ 0.22433188,  0.58393295,  1.3774936 , ..., -0.58312392,
#         -0.57273139, -1.09278791],
#        [ 0.13123255,  0.01077067,  1.03095433, ..., -0.58312392,
#         -0.57273139, -1.09278791],
#        [ 1.1656695 ,  0.29735181,  0.33787579, ...,  1.71490137,
#         -0.57273139,  0.91509065]])

# %%
import tensorflow
from tensorflow import keras
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense
# Out:
# 2025-08-15 17:55:34.128378: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1755280534.396710      13 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1755280534.474717      13 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
model = Sequential()

model.add(Dense(11,activation='relu', input_dim=11))
model.add(Dense(11,activation='relu'))
model.add(Dense(1,activation='sigmoid'))
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2025-08-15 17:55:49.934885: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:152] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 11)             │           132 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 11)             │           132 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │            12 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 276 (1.08 KB)
#  Trainable params: 276 (1.08 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# model compile

# %%
model.compile(loss='binary_crossentropy', optimizer='Adam', metrics=['accuracy'])

# %%
history = model.fit(x_train,y_train, epochs=100, validation_split=0.2)
# Out:
# Epoch 1/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.7913 - loss: 0.5370 - val_accuracy: 0.7975 - val_loss: 0.4700
# Epoch 2/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8039 - loss: 0.4537 - val_accuracy: 0.7987 - val_loss: 0.4409
# Epoch 3/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8025 - loss: 0.4435 - val_accuracy: 0.8087 - val_loss: 0.4250
# Epoch 4/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8070 - loss: 0.4373 - val_accuracy: 0.8119 - val_loss: 0.4143
# Epoch 5/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8172 - loss: 0.4131 - val_accuracy: 0.8213 - val_loss: 0.4012
# Epoch 6/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8317 - loss: 0.4065 - val_accuracy: 0.8306 - val_loss: 0.3879
# Epoch 7/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8468 - loss: 0.3816 - val_accuracy: 0.8400 - val_loss: 0.3761
# Epoch 8/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8464 - loss: 0.3877 - val_accuracy: 0.8475 - val_loss: 0.3652
# Epoch 9/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8504 - loss: 0.3649 - val_accuracy: 0.8500 - val_loss: 0.3551
# Epoch 10/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8526 - loss: 0.3729 - val_accuracy: 0.8537 - val_loss: 0.3485
# Epoch 11/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8538 - loss: 0.3595 - val_accuracy: 0.8475 - val_loss: 0.3471
# Epoch 12/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8613 - loss: 0.3480 - val_accuracy: 0.8444 - val_loss: 0.3478
# Epoch 13/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8551 - loss: 0.3581 - val_accuracy: 0.8512 - val_loss: 0.3448
# Epoch 14/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8677 - loss: 0.3355 - val_accuracy: 0.8487 - val_loss: 0.3434
# Epoch 15/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8592 - loss: 0.3418 - val_accuracy: 0.8475 - val_loss: 0.3448
# Epoch 16/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8572 - loss: 0.3451 - val_accuracy: 0.8487 - val_loss: 0.3438
# Epoch 17/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8634 - loss: 0.3414 - val_accuracy: 0.8500 - val_loss: 0.3435
# Epoch 18/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8553 - loss: 0.3526 - val_accuracy: 0.8519 - val_loss: 0.3420
# Epoch 19/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8578 - loss: 0.3486 - val_accuracy: 0.8506 - val_loss: 0.3418
# Epoch 20/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8653 - loss: 0.3330 - val_accuracy: 0.8506 - val_loss: 0.3422
# Epoch 21/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8663 - loss: 0.3362 - val_accuracy: 0.8537 - val_loss: 0.3418
# Epoch 22/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8623 - loss: 0.3400 - val_accuracy: 0.8519 - val_loss: 0.3420
# Epoch 23/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8689 - loss: 0.3220 - val_accuracy: 0.8594 - val_loss: 0.3412
# Epoch 24/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8624 - loss: 0.3335 - val_accuracy: 0.8575 - val_loss: 0.3406
# Epoch 25/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8619 - loss: 0.3293 - val_accuracy: 0.8525 - val_loss: 0.3433
# Epoch 26/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8593 - loss: 0.3443 - val_accuracy: 0.8512 - val_loss: 0.3424
# Epoch 27/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8697 - loss: 0.3245 - val_accuracy: 0.8594 - val_loss: 0.3402
# Epoch 28/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8589 - loss: 0.3356 - val_accuracy: 0.8544 - val_loss: 0.3408
# Epoch 29/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8543 - loss: 0.3434 - val_accuracy: 0.8594 - val_loss: 0.3398
# Epoch 30/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8655 - loss: 0.3309 - val_accuracy: 0.8594 - val_loss: 0.3403
# Epoch 31/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8557 - loss: 0.3468 - val_accuracy: 0.8544 - val_loss: 0.3411
# Epoch 32/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8661 - loss: 0.3317 - val_accuracy: 0.8569 - val_loss: 0.3406
# Epoch 33/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8639 - loss: 0.3347 - val_accuracy: 0.8481 - val_loss: 0.3420
# Epoch 34/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8606 - loss: 0.3394 - val_accuracy: 0.8544 - val_loss: 0.3413
# Epoch 35/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8637 - loss: 0.3366 - val_accuracy: 0.8537 - val_loss: 0.3413
# Epoch 36/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8535 - loss: 0.3448 - val_accuracy: 0.8487 - val_loss: 0.3439
# Epoch 37/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.
100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8726 - loss: 0.3102 - val_accuracy: 0.8575 - val_loss: 0.3446
# Epoch 97/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8638 - loss: 0.3203 - val_accuracy: 0.8512 - val_loss: 0.3453
# Epoch 98/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8667 - loss: 0.3227 - val_accuracy: 0.8519 - val_loss: 0.3458
# Epoch 99/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8653 - loss: 0.3236 - val_accuracy: 0.8481 - val_loss: 0.3471
# Epoch 100/100
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8668 - loss: 0.3261 - val_accuracy: 0.8581 - val_loss: 0.3445

# %%
model.layers[0].get_weights()
# Out:
# [array([[ 1.1505260e-01,  3.5957980e-01, -3.0978674e-01, -1.9500899e-01,
#          -2.1018233e-02,  2.5272366e-01, -8.4957987e-02,  3.3333234e-02,
#           1.5688336e-01, -1.9646417e-01,  1.4223872e-01],
#         [ 6.5632991e-02, -6.9721752e-01, -4.7835294e-02,  5.3901261e-01,
#           1.0631164e+00, -3.7011144e-01, -3.3896354e-01,  5.5946672e-01,
#          -2.0369828e-01,  8.5832387e-01, -5.8093792e-01],
#         [ 1.1892873e-02, -1.3388750e-01, -3.8701391e-01, -3.6860573e-01,
#           1.4869246e-01, -6.1869907e-01,  2.1610919e-01,  1.8111263e-01,
#           8.2834132e-02, -1.4150630e-01,  2.9442468e-01],
#         [ 2.7030110e-02, -4.0527341e-01,  4.6628982e-01, -1.3198979e-01,
#          -3.4076861e-01, -2.0228587e-01, -3.7260798e-01, -4.0785974e-01,
#          -5.9986871e-01,  4.4930229e-01,  1.4785030e-01],
#         [ 1.0409243e+00,  2.3859613e-02, -2.1697457e-01, -9.4886333e-01,
#          -2.5526279e-01,  5.3093982e-01, -1.1441448e-01, -1.7407171e-01,
#          -1.0756811e+00,  4.6553120e-01, -3.2031977e-01],
#         [ 9.6509792e-02,  6.1635613e-02,  3.0298936e-01, -8.0621362e-02,
#           3.3755738e-02, -5.4719377e-01,  1.8126156e-02, -4.0331841e-02,
#           1.7858833e-02,  1.8690860e-01, -9.4309360e-01],
#         [-6.8646282e-02, -1.5031973e-01,  4.6866694e-01, -2.6938689e-01,
#           2.3708922e-01,  3.8927978e-01, -1.9611457e-02,  9.0168297e-01,
#          -5.8649320e-02,  3.9174771e-01,  3.2454902e-01],
#         [ 9.6914209e-02,  1.2626284e-01,  4.4371018e-01,  4.5399159e-02,
#           1.3669042e-02, -6.1963156e-02, -2.1150856e-01,  8.3896495e-02,
#          -7.2161304e-03, -2.1347831e-01, -3.0803072e-01],
#         [ 1.2514320e-01,  2.0513119e-01,  1.1933552e-01,  1.8963720e-01,
#          -7.2770089e-02, -6.0289931e-01, -1.2335628e-01,  1.1321069e-01,
#           3.6225393e-01, -1.5007140e-01,  1.8696528e-02],
#         [ 3.3206671e-01, -1.9009994e-01, -3.1577063e-01,  2.0076130e-01,
#           6.0463764e-02, -2.9450506e-01,  3.2865432e-01,  3.6316478e-01,
#           5.4927547e-02, -7.6816559e-02,  6.2479305e-01],
#         [-1.4792426e-01,  3.0262750e-02, -1.6512051e-01,  3.2847989e-01,
#          -7.9629757e-04,  8.7731868e-01,  2.2794731e-01,  1.4517784e-01,
#          -4.6669066e-02,  1.6420148e-01,  2.2972628e-01]], dtype=float32),
#  array([-0.6956467 ,  0.8806    ,  0.10922913,  0.08197235,  0.17130066,
#          0.3580378 ,  0.84548974, -0.0762347 , -0.28269258, -0.2724627 ,
#          0.02307084], dtype=float32)]

# %%
model.layers[1].get_weights()
# Out:
# [array([[-0.22646275,  0.37780386, -0.37758818, -0.16014612,  1.0180032 ,
#          -0.75718385, -0.24528334,  0.6168321 , -0.12228297, -0.8217141 ,
#           0.01319969],
#         [ 0.16136612, -0.8698985 , -0.08567806,  0.19129571, -0.71957237,
#           0.48485157,  0.24205133,  0.13785978,  0.6170628 , -0.19624011,
#           0.07751095],
#         [ 0.00703329,  0.06664584,  0.43068627,  0.09468929,  0.16183719,
#          -0.35069805,  0.28012413, -0.48720685, -0.32077727,  0.10978716,
#           0.3031063 ],
#         [-0.30342734, -0.6028239 ,  0.19841759, -0.25838068,  0.57324004,
#           0.14616191,  0.1040738 , -0.7590678 , -0.25964046, -0.44725987,
#           0.16625752],
#         [ 0.56009674,  0.32332388,  0.4388219 , -0.23931906,  0.6976106 ,
#           0.33371565, -0.2635222 ,  0.32112655,  0.29792157, -0.03188312,
#          -0.2929474 ],
#         [ 0.05169223,  0.1601312 , -0.36311963, -0.23211691,  0.24820286,
#          -0.2945378 ,  0.3486532 ,  0.37949285, -0.49873126,  0.37688354,
#           0.22875853],
#         [ 0.5499174 , -0.07251251,  0.06365762,  0.44877055, -0.62065566,
#          -0.14906397,  0.06984159, -0.31086344, -0.48629302, -0.36715275,
#           0.15455772],
#         [ 0.471569  , -0.5209838 ,  0.18467616,  0.0091466 , -0.19568892,
#          -0.05240892, -0.45977387, -0.38154852,  0.6182417 ,  0.55514777,
#           0.15118529],
#         [-0.7125028 , -0.49885944,  0.263034  , -0.28640515,  0.43919462,
#           0.6608066 , -0.09948729,  0.5663953 ,  0.35958284, -0.78601056,
#          -0.09222966],
#         [ 0.33520225,  0.28257778, -0.39772528, -0.17064966,  0.17392552,
#          -0.17808402, -0.33901852,  0.59721786,  0.1913048 ,  0.8243753 ,
#          -0.53814024],
#         [-0.98103017, -0.6227457 ,  0.39191648,  0.07795373,  0.14762048,
#          -0.3187054 ,  0.00370679,  0.19489124,  0.42920512,  0.16202107,
#           0.42333308]], dtype=float32),
#  array([ 0.25845852,  0.60184574,  0.19075854,  0.6335722 ,  0.16625015,
#          0.3092617 ,  0.50359005,  0.00255576, -0.39698935,  0.16523403,
#          0.44238585], dtype=float32)]

# %%
y_log = model.predict(x_test)
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %%
y_pred = np.where(y_log>0.5,1,0)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.8655

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
