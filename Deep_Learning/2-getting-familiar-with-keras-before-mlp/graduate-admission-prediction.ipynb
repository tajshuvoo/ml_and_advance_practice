# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/graduate-admissions/Admission_Predict.csv
# /kaggle/input/graduate-admissions/Admission_Predict_Ver1.1.csv

# %%
df = pd.read_csv('/kaggle/input/graduate-admissions/Admission_Predict_Ver1.1.csv')

# %%
df.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0           1        337          118                  4  4.5   4.5  9.65
# 1           2        324          107                  4  4.0   4.5  8.87
# 2           3        316          104                  3  3.0   3.5  8.00
# 3           4        322          110                  3  3.5   2.5  8.67
# 4           5        314          103                  2  2.0   3.0  8.21
#
#    Research  Chance of Admit
# 0         1              0.92
# 1         1              0.76
# 2         1              0.72
# 3         1              0.80
# 4         0              0.65

# %%
df.shape
# Out:
# (500, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Serial No.         500 non-null    int64
#  1   GRE Score          500 non-null    int64
#  2   TOEFL Score        500 non-null    int64
#  3   University Rating  500 non-null    int64
#  4   SOP                500 non-null    float64
#  5   LOR                500 non-null    float64
#  6   CGPA               500 non-null    float64
#  7   Research           500 non-null    int64
#  8   Chance of Admit    500 non-null    float64
# dtypes: float64(4), int64(5)
# memory usage: 35.3 KB

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.drop(columns=['Serial No.'],inplace=True)

# %%
df.head()
# Out:
#    GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  Research  \
# 0        337          118                  4  4.5   4.5  9.65         1
# 1        324          107                  4  4.0   4.5  8.87         1
# 2        316          104                  3  3.0   3.5  8.00         1
# 3        322          110                  3  3.5   2.5  8.67         1
# 4        314          103                  2  2.0   3.0  8.21         0
#
#    Chance of Admit
# 0              0.92
# 1              0.76
# 2              0.72
# 3              0.80
# 4              0.65

# %%
x = df.iloc[:,0:-1]
y= df.iloc[:,-1]

# %%
x
# Out:
#      GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  Research
# 0          337          118                  4  4.5   4.5  9.65         1
# 1          324          107                  4  4.0   4.5  8.87         1
# 2          316          104                  3  3.0   3.5  8.00         1
# 3          322          110                  3  3.5   2.5  8.67         1
# 4          314          103                  2  2.0   3.0  8.21         0
# ..         ...          ...                ...  ...   ...   ...       ...
# 495        332          108                  5  4.5   4.0  9.02         1
# 496        337          117                  5  5.0   5.0  9.87         1
# 497        330          120                  5  4.5   5.0  9.56         1
# 498        312          103                  4  4.0   5.0  8.43         0
# 499        327          113                  4  4.5   4.5  9.04         0
#
# [500 rows x 7 columns]

# %%
y
# Out:
# 0      0.92
# 1      0.76
# 2      0.72
# 3      0.80
# 4      0.65
#        ...
# 495    0.87
# 496    0.96
# 497    0.93
# 498    0.73
# 499    0.84
# Name: Chance of Admit , Length: 500, dtype: float64

# %%
from sklearn.model_selection import train_test_split
x_train, x_test , y_train ,y_test = train_test_split(x,y, test_size=0.2, random_state= 1)

# %%
x_train
# Out:
#      GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  Research
# 238        310          104                  3  2.0   3.5  8.37         0
# 438        318          110                  1  2.5   3.5  8.54         1
# 475        300          101                  3  3.5   2.5  7.88         0
# 58         300           99                  1  3.0   2.0  6.80         1
# 380        322          104                  3  3.5   4.0  8.84         1
# ..         ...          ...                ...  ...   ...   ...       ...
# 255        307          110                  4  4.0   4.5  8.37         0
# 72         321          111                  5  5.0   5.0  9.45         1
# 396        325          107                  3  3.0   3.5  9.11         1
# 235        326          111                  5  4.5   4.0  9.23         1
# 37         300          105                  1  1.0   2.0  7.80         0
#
# [400 rows x 7 columns]

# %%
from sklearn.preprocessing import MinMaxScaler
sc = MinMaxScaler()

x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)

# %%
x_train
# Out:
# array([[0.4       , 0.42857143, 0.5       , ..., 0.57142857, 0.50320513,
#         0.        ],
#        [0.56      , 0.64285714, 0.        , ..., 0.57142857, 0.55769231,
#         1.        ],
#        [0.2       , 0.32142857, 0.5       , ..., 0.28571429, 0.34615385,
#         0.        ],
#        ...,
#        [0.7       , 0.53571429, 0.5       , ..., 0.57142857, 0.74038462,
#         1.        ],
#        [0.72      , 0.67857143, 1.        , ..., 0.71428571, 0.77884615,
#         1.        ],
#        [0.2       , 0.46428571, 0.        , ..., 0.14285714, 0.32051282,
#         0.        ]])

# %%
import tensorflow
from tensorflow import keras
from keras import Sequential
from keras.layers import Dense
# Out:
# 2025-08-20 09:27:05.859604: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1755682026.105503      13 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1755682026.177007      13 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
model = Sequential()

model.add(Dense(7,activation='relu', input_dim=7))
model.add(Dense(7,activation='relu'))
model.add(Dense(1, activation='linear'))# regression output node linear activation linear
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2025-08-20 09:27:20.924094: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:152] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 7)              │            56 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 7)              │            56 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │             8 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 120 (480.00 B)
#  Trainable params: 120 (480.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(loss='mean_squared_error', optimizer='Adam', metrics=['r2_score'])

# %%
history= model.fit(x_train, y_train, epochs=100 , validation_split=0.2 )
# Out:
# Epoch 1/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - loss: 0.8164 - r2_score: -37.6745 - val_loss: 0.6283 - val_r2_score: -43.1861
# Epoch 2/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.5754 - r2_score: -26.1969 - val_loss: 0.4305 - val_r2_score: -29.2750
# Epoch 3/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.3926 - r2_score: -17.5465 - val_loss: 0.2803 - val_r2_score: -18.7096
# Epoch 4/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2623 - r2_score: -11.8355 - val_loss: 0.1758 - val_r2_score: -11.3621
# Epoch 5/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1641 - r2_score: -6.6274 - val_loss: 0.1101 - val_r2_score: -6.7451
# Epoch 6/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0957 - r2_score: -3.8712 - val_loss: 0.0708 - val_r2_score: -3.9806
# Epoch 7/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0650 - r2_score: -2.2694 - val_loss: 0.0500 - val_r2_score: -2.5186
# Epoch 8/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0494 - r2_score: -1.5107 - val_loss: 0.0399 - val_r2_score: -1.8032
# Epoch 9/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0380 - r2_score: -0.7480 - val_loss: 0.0356 - val_r2_score: -1.5009
# Epoch 10/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0344 - r2_score: -0.5722 - val_loss: 0.0339 - val_r2_score: -1.3813
# Epoch 11/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0350 - r2_score: -0.6774 - val_loss: 0.0329 - val_r2_score: -1.3159
# Epoch 12/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0314 - r2_score: -0.4103 - val_loss: 0.0322 - val_r2_score: -1.2618
# Epoch 13/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0303 - r2_score: -0.5487 - val_loss: 0.0314 - val_r2_score: -1.2066
# Epoch 14/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0300 - r2_score: -0.5772 - val_loss: 0.0306 - val_r2_score: -1.1516
# Epoch 15/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0294 - r2_score: -0.3561 - val_loss: 0.0298 - val_r2_score: -1.0938
# Epoch 16/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0273 - r2_score: -0.3576 - val_loss: 0.0290 - val_r2_score: -1.0400
# Epoch 17/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0280 - r2_score: -0.4143 - val_loss: 0.0282 - val_r2_score: -0.9861
# Epoch 18/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0262 - r2_score: -0.3064 - val_loss: 0.0275 - val_r2_score: -0.9349
# Epoch 19/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0269 - r2_score: -0.2699 - val_loss: 0.0268 - val_r2_score: -0.8826
# Epoch 20/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0251 - r2_score: -0.1311 - val_loss: 0.0261 - val_r2_score: -0.8343
# Epoch 21/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0244 - r2_score: -0.3027 - val_loss: 0.0254 - val_r2_score: -0.7872
# Epoch 22/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0228 - r2_score: -0.0505 - val_loss: 0.0248 - val_r2_score: -0.7424
# Epoch 23/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0231 - r2_score: -0.0686 - val_loss: 0.0241 - val_r2_score: -0.6982
# Epoch 24/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0241 - r2_score: -0.1721 - val_loss: 0.0235 - val_r2_score: -0.6538
# Epoch 25/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0212 - r2_score: 0.0257 - val_loss: 0.0229 - val_r2_score: -0.6132
# Epoch 26/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0204 - r2_score: 0.0237 - val_loss: 0.0224 - val_r2_score: -0.5724
# Epoch 27/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0221 - r2_score: -0.0027 - val_loss: 0.0218 - val_r2_score: -0.5313
# Epoch 28/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0182 - r2_score: 0.1072 - val_loss: 0.0212 - val_r2_score: -0.4933
# Epoch 29/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0202 - r2_score: 0.0185 - val_loss: 0.0207 - val_r2_score: -0.4553
# Epoch 30/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0201 - r2_score: 0.1520 - val_loss: 0.0202 - val_r2_score: -0.4190
# Epoch 31/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0186 - r2_score: 0.0614 - val_loss: 0.0197 - val_r2_score: -0.3840
# Epoch 32/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0180 - r2_score: 0.1664 - val_loss: 0.0192 - val_r2_score: -0.3493
# Epoch 33/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0189 - r2_score: 0.0071 - val_loss: 0.0187 - val_r2_score: -0.3152
# Epoch 34/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0180 - r2_score: -0.0806 - val_loss: 0.0182 - val_r2_score: -0.2824
# Epoch 35/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0174 - r2_score: 0.1672 - val_loss: 0.0178 - val_r2_score: -0.2502
# Epoch 36/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0165 - r2_score: 0.1932 - val_loss: 0.0173 - val_r2_score: -0.2183
# Epoch 37/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0174 - r2_score: 0.1833 - val_loss: 0.0169 - val_r2_score: -0.1874
# Epoch 38/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0166 - r2_score: 0.2252 - val_loss: 0.0165 - val_r2_score: -0.1586
# Epoch 39/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0148 - r2_score: 0.3429 - val_loss: 0.0161 - val_r2_score: -0.1302
# Epoch 40/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0164 - r2_score: 0.2354 - val_loss: 0.0157 - val_r2_score: -0.1018
# Epoch 41/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0152 - r2_score: 0.2277 - val_loss: 0.0153 - val_r2_score: -0.0758
# Epoch 42/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0146 - r2_score: 0.2858 - val_loss: 0.0149 - val_r2_score: -0.0495
# Epoch 43/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0147 - r2_score: 0.2984 - val_loss: 0.0146 - val_r2_score: -0.0244
# Epoch 44/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0133 - r2_score: 0.3786 - val_loss: 0.0142 - val_r2_score: -4.2951e-04
# Epoch 45/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0123 - r2_score: 0.4404 - val_loss: 0.0139 - val_r2_score: 0.0237
# Epoch 46/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0134 - r2_score: 0.3500 - val_loss: 0.0136 - val_r2_score: 0.0465
# Epoch 47/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0128 - r2_score: 0.3466 - val_loss: 0.0132 - val_r2_score: 0.0685
# Epoch 48/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0127 - r2_score: 0.4212 - val_loss: 0.0129 - val_r2_score: 0.0899
# Epoch 49/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0116 - r2_score: 0.3973 - val_loss: 0.0127 - val_r2_score: 0.1095
# Epoch 50/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0116 - r2_score: 0.4414 - val_loss: 0.0124 - val_r2_score: 0.1300
# Epoch 51/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0125 - r2_score: 0.4026 - val_loss: 0.0121 - val_r2_score: 0.1495
# Epoch 52/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0115 - r2_score: 0.4658 - val_loss: 0.0118 - val_r2_score: 0.1669
# Epoch 53/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0108 - r2_score: 0.4617 - val_loss: 0.0116 - val_r2_score: 0.1852
# Epoch 54/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0108 - r2_score: 0.5101 - val_loss: 0.0113 - val_r2_score: 0.2031
# Epoch 55/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0112 - r2_score: 0.4700 - val_loss: 0.0111 - val_r2_score: 0.2215
# Epoch 56/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0112 - r2_score: 0.5021 - val_loss: 0.0108 - val_r2_score: 0.2382
# Epoch 57/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0105 - r2_score: 0.5226 - val_loss: 0.0106 - val_r2_score: 0.2536
# Epoch 58/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0100 - r2_score: 0.5200 - val_loss: 0.0104 - val_r2_score: 0.2686
# Epoch 59/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0100 - r2_score: 0.5049 - val_loss: 0.0102 - val_r2_score: 0.2845
# Epoch 60/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0107 - r2_score: 0.5105 - val_loss: 0.0099 - val_r2_score: 0.3006
# Epoch 61/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0081 - r2_score: 0.6014 - val_loss: 0.0098 - val_r2_score: 0.3138
# Epoch 62/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0093 - r2_score: 0.5292 - val_loss: 0.0095 - val_r2_score: 0.3285
# Epoch 63/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0097 - r2_score: 0.5026 - val_loss: 0.0094 - val_r2_score: 0.3410
# Epoch 64/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0089 - r2_score: 0.5695 - val_loss: 0.0092 - val_r2_score: 0.3537
# Epoch 65/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0094 - r2_score: 0.5363 - val_loss: 0.0090 - val_r2_score: 0.3672
# Epoch 66/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0100 - r2_score: 0.5534 - val_loss: 0.0088 - val_r2_score: 0.3800
# Epoch 67/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0075 - r2_score: 0.6618 - val_loss: 0.0087 - val_r2_score: 0.3908
# Epoch 68/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0086 - r2_score: 0.6268 - val_loss: 0.0085 - val_r2_score: 0.4034
# Epoch 69/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0076 - r2_score: 0.6214 - val_loss: 0.0083 - val_r2_score: 0.4134
# Epoch 70/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0082 - r2_score: 0.6052 - val_loss: 0.0082 - val_r2_score: 0.4247
# Epoch 71/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0082 - r2_score: 0.6330 - val_loss: 0.0080 - val_r2_score: 0.4361
# Epoch 72/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0081 - r2_score: 0.6369 - val_loss: 0.0079 - val_r2_score: 0.4466
# Epoch 73/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0081 - r2_score: 0.5657 - val_loss: 0.0077 - val_r2_score: 0.4554
# Epoch 74/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0070 - r2_score: 0.6401 - val_loss: 0.0076 - val_r2_score: 0.4638
# Epoch 75/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0067 - r2_score: 0.6927 - val_loss: 0.0075 - val_r2_score: 0.4733
# Epoch 76/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0067 - r2_score: 0.6672 - val_loss: 0.0073 - val_r2_score: 0.4840
# Epoch 77/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0081 - r2_score: 0.6186 - val_loss: 0.0072 - val_r2_score: 0.4929
# Epoch 78/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0072 - r2_score: 0.6249 - val_loss: 0.0071 - val_r2_score: 0.5018
# Epoch 79/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0066 - r2_score: 0.6919 - val_loss: 0.0070 - val_r2_score: 0.5063
# Epoch 80/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0081 - r2_score: 0.6322 - val_loss: 0.0069 - val_r2_score: 0.5154
# Epoch 81/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0073 - r2_score: 0.6487 - val_loss: 0.0068 - val_r2_score: 0.5240
# Epoch 82/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0069 - r2_score: 0.6908 - val_loss: 0.0067 - val_r2_score: 0.5285
# Epoch 83/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0072 - r2_score: 0.6691 - val_loss: 0.0066 - val_r2_score: 0.5389
# Epoch 84/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0064 - r2_score: 0.6948 - val_loss: 0.0064 - val_r2_score: 0.5469
# Epoch 85/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0067 - r2_score: 0.6961 - val_loss: 0.0064 - val_r2_score: 0.5493
# Epoch 86/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0063 - r2_score: 0.6834 - val_loss: 0.0063 - val_r2_score: 0.5578
# Epoch 87/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0065 - r2_score: 0.6841 - val_loss: 0.0062 - val_r2_score: 0.5629
# Epoch 88/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0060 - r2_score: 0.7109 - val_loss: 0.0062 - val_r2_score: 0.5672
# Epoch 89/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0059 - r2_score: 0.7308 - val_loss: 0.0060 - val_r2_score: 0.5749
# Epoch 90/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0060 - r2_score: 0.7047 - val_loss: 0.0060 - val_r2_score: 0.5774
# Epoch 91/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0066 - r2_score: 0.7184 - val_loss: 0.0059 - val_r2_score: 0.5863
# Epoch 92/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0063 - r2_score: 0.7251 - val_loss: 0.0058 - val_r2_score: 0.5892
# Epoch 93/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0060 - r2_score: 0.7144 - val_loss: 0.0057 - val_r2_score: 0.5958
# Epoch 94/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0063 - r2_score: 0.6974 - val_loss: 0.0057 - val_r2_score: 0.6004
# Epoch 95/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0060 - r2_score: 0.7154 - val_loss: 0.0057 - val_r2_score: 0.6024
# Epoch 96/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0065 - r2_score: 0.7257 - val_loss: 0.0056 - val_r2_score: 0.6080
# Epoch 97/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0062 - r2_score: 0.7250 - val_loss: 0.0055 - val_r2_score: 0.6150
# Epoch 98/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0047 - r2_score: 0.7707 - val_loss: 0.0054 - val_r2_score: 0.6194
# Epoch 99/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0053 - r2_score: 0.7146 - val_loss: 0.0054 - val_r2_score: 0.6193
# Epoch 100/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0055 - r2_score: 0.7512 - val_loss: 0.0054 - val_r2_score: 0.6208

# %%
y_pred = model.predict(x_test)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step

# %%
from sklearn.metrics import r2_score
r2_score(y_test, y_pred)
# Out:
# 0.7360538739164074

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
