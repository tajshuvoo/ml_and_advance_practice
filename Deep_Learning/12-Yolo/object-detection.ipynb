# %%
# !pip install ultralytics
# Out:
# ...
#   Using cached mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 6.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.9/37.9 MB 4.4 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.3/5.3 MB 3.7 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.6/73.6 MB 4.0 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 3.5 MB/s eta 0:00:00a 0:00:01
# Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 3.7 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.2/35.2 MB 4.3 MB/s eta 0:00:0000:0100:01
# ...
#   Attempting uninstall: numpy━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  3/12 [polars]
#     Found existing installation: numpy 1.26.4━━━━━━━━━━━━━━━━━  3/12 [polars]
#     Uninstalling numpy-1.26.4:90m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  3/12 [polars]
# ...

# %%
# !yolo task=detect mode=predict model=yolov8n.pt source="sofa.jpg"
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/Users/tajbirhasanshuvo/Library/Application Support/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# Ultralytics 8.3.192 🚀 Python-3.10.16 torch-2.8.0 CPU (Apple M1 Pro)
# YOLOv8n summary (fused): 72 layers, 3,151,904 parameters, 0 gradients, 8.7 GFLOPs
#
# image 1/1 /Users/tajbirhasanshuvo/academicfiles/ml_and_advance_practice/Deep_Learning/12-Yolo/sofa.jpg: 640x640 1 couch, 101.3ms
# Speed: 7.2ms preprocess, 101.3ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !yolo task=segment mode=predict model=yolov8n-seg.pt source="sofa.jpg"
# Out:
# ...
# Ultralytics 8.3.192 🚀 Python-3.10.16 torch-2.8.0 CPU (Apple M1 Pro)
# YOLOv8n-seg summary (fused): 85 layers, 3,404,320 parameters, 0 gradients, 12.0 GFLOPs
#
# image 1/1 /Users/tajbirhasanshuvo/academicfiles/ml_and_advance_practice/Deep_Learning/12-Yolo/sofa.jpg: 640x640 1 backpack, 1 couch, 129.2ms
# Speed: 4.8ms preprocess, 129.2ms inference, 10.5ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/segment/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
from ultralytics import YOLO

model = YOLO('yolov8n-seg.pt')
model.predict(source='sofa.jpg')
# Out:
# image 1/1 /Users/tajbirhasanshuvo/academicfiles/ml_and_advance_practice/Deep_Learning/12-Yolo/sofa.jpg: 640x640 1 backpack, 1 couch, 170.6ms
# Speed: 10.4ms preprocess, 170.6ms inference, 9.0ms postprocess per image at shape (1, 3, 640, 640)
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: ultralytics.engine.results.Masks object
# ...

# %%
# !yolo task=classify mode=predict model=yolov8n-cls.pt source="sofa.jpg"
# Out:
# ...
# Ultralytics 8.3.192 🚀 Python-3.10.16 torch-2.8.0 CPU (Apple M1 Pro)
# YOLOv8n-cls summary (fused): 30 layers, 2,715,880 parameters, 0 gradients, 4.3 GFLOPs
#
# Unable to revert mtime: /Library/Fonts
# image 1/1 /Users/tajbirhasanshuvo/academicfiles/ml_and_advance_practice/Deep_Learning/12-Yolo/sofa.jpg: 224x224 studio_couch 0.35, radiator 0.18, Rhodesian_ridgeback 0.08, dumbbell 0.07, cowboy_boot 0.04, 17.0ms
# Speed: 10.6ms preprocess, 17.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/classify/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
from ultralytics import YOLO

model = YOLO()

model.train(data="data.yaml", epochs=50) #data.yaml should have train val path with with classes
