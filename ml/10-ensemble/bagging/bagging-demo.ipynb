# %%
from sklearn.datasets import make_classification
from sklearn.metrics import accuracy_score
from sklearn.ensemble import BaggingClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split

# %%
x,y = make_classification(n_samples=10000 , n_features=10 , n_informative=3)

# %%
x_train , x_test , y_train , y_test = train_test_split(x,y , test_size=0.2, random_state=42)

# %%
dt = DecisionTreeClassifier(random_state=42)
dt.fit(x_train,y_train)
y_pred = dt.predict(x_test)

print(accuracy_score(y_test,y_pred))
# Out:
# 0.925

# %% [markdown]
# #Bagging

# %%
bag = BaggingClassifier(
    estimator=DecisionTreeClassifier(),
    n_estimators=500,
    max_samples=0.25,
    bootstrap=True,
    random_state=42
)

# %%
bag.fit(x_train,y_train)
# Out:
# BaggingClassifier(estimator=DecisionTreeClassifier(), max_samples=0.25,
#                   n_estimators=500, random_state=42)

# %%
y_pred = bag.predict(x_test)

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.9455

# %%
bag.estimators_samples_[0].shape
# Out:
# (2000,)

# %% [markdown]
# #Bagging using SVM

# %%
dt = SVC(random_state=42)
dt.fit(x_train,y_train)
y_pred = dt.predict(x_test)

print(accuracy_score(y_test,y_pred))
# Out:
# 0.925

# %%
bag = BaggingClassifier(
    estimator=SVC(),
    n_estimators=500,
    max_samples=0.25,
    bootstrap=True,
    random_state=42
)

# %%
bag.fit(x_train,y_train)
y_pred = bag.predict(x_test)
accuracy_score(y_test,y_pred)
# Out:
# 0.9235

# %% [markdown]
# #Pasting

# %%
bag = BaggingClassifier(
    estimator=DecisionTreeClassifier(),
    n_estimators=500,
    max_samples=0.25,
    bootstrap=False,
    random_state=42,
    verbose=1,
    n_jobs=-1
)

# %%
bag.fit(x_train,y_train)
y_pred = bag.predict(x_test)
accuracy_score(y_test,y_pred)
# Out:
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done   2 out of   8 | elapsed:    3.7s remaining:   11.2s
# [Parallel(n_jobs=8)]: Done   8 out of   8 | elapsed:    3.9s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done   2 out of   8 | elapsed:    0.1s remaining:    0.2s
# [Parallel(n_jobs=8)]: Done   8 out of   8 | elapsed:    0.1s finished
# 0.947

# %% [markdown]
# #Random Subspaces

# %%
bag = BaggingClassifier(
    estimator=DecisionTreeClassifier(),
    n_estimators=500,
    max_samples=1,
    bootstrap=False,
    random_state=42,
    max_features=0.5,
    bootstrap_features=True,
    verbose=1,
    n_jobs=-1
)

# %%
bag.fit(x_train,y_train)
y_pred = bag.predict(x_test)
accuracy_score(y_test,y_pred)
# Out:
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done   2 out of   8 | elapsed:    0.1s remaining:    0.4s
# [Parallel(n_jobs=8)]: Done   8 out of   8 | elapsed:    0.2s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done   2 out of   8 | elapsed:    0.0s remaining:    0.1s
# [Parallel(n_jobs=8)]: Done   8 out of   8 | elapsed:    0.0s finished
# 0.494

# %%
bag.estimators_features_[0].shape
# Out:
# (5,)

# %% [markdown]
# #Random Patches

# %%
bag = BaggingClassifier(
    estimator=DecisionTreeClassifier(),
    n_estimators=500,
    max_samples=0.25,
    bootstrap=True,
    random_state=42,
    max_features=0.5,
    bootstrap_features=True,
    verbose=1,
    n_jobs=-1
)

# %%
bag.fit(x_train,y_train)
y_pred = bag.predict(x_test)
accuracy_score(y_test,y_pred)
# Out:
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done   2 out of   8 | elapsed:    0.7s remaining:    2.1s
# [Parallel(n_jobs=8)]: Done   8 out of   8 | elapsed:    0.9s finished
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done   2 out of   8 | elapsed:    0.0s remaining:    0.1s
# [Parallel(n_jobs=8)]: Done   8 out of   8 | elapsed:    0.1s finished
# 0.936

# %% [markdown]
# OOB SCORE

# %%
bag = BaggingClassifier(
    estimator=DecisionTreeClassifier(),
    n_estimators=500,
    max_samples=0.25,
    bootstrap=True,
    random_state=42,
    oob_score=True
)

# %%
bag.fit(x_train,y_train)
y_pred = bag.predict(x_test)
accuracy_score(y_test,y_pred)
# Out:
# 0.9455

# %%
bag.oob_score_
# Out:
# 0.946625

# %% [markdown]
# #Grid Search  CV

# %%
from sklearn.model_selection import GridSearchCV

# %%
parameters = {
    'estimator': [ None, DecisionTreeClassifier()],
    'n_estimators': [50, 100, 500],
    'max_samples': [ 0.7, 1],
    'bootstrap': [True, False],
    'max_features': [ 0.7, 1.0]
}

# %%
srch = GridSearchCV(BaggingClassifier(random_state=1,n_jobs=-1),param_grid= parameters , cv=5 , n_jobs=-1 ,verbose=1)

# %%
srch.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# GridSearchCV(cv=5, estimator=BaggingClassifier(n_jobs=-1, random_state=1),
#              n_jobs=-1,
#              param_grid={'bootstrap': [True, False],
#                          'estimator': [None, DecisionTreeClassifier()],
#                          'max_features': [0.7, 1.0], 'max_samples': [0.7, 1],
#                          'n_estimators': [50, 100, 500]},
#              verbose=1)

# %%
srch.best_params_
# Out:
# {'bootstrap': True,
#  'estimator': None,
#  'max_features': 1.0,
#  'max_samples': 0.7,
#  'n_estimators': 100}

# %%
srch.best_score_
# Out:
# 0.9491249999999999
