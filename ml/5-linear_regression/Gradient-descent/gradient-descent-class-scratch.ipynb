# %%
from sklearn.datasets import make_regression
import matplotlib.pyplot as plt 
import numpy as np

# %%
X,y = make_regression(n_samples=100, n_features=1,n_informative=1, n_targets=1, noise=20)

# %%
X
# Out:
# array([[-1.50798687],
#        [ 0.82767804],
#        [ 0.57615392],
#        [-0.29973576],
#        [-0.14158376],
#        [ 0.31548326],
#        [ 1.09741555],
#        [-0.04466404],
#        [ 0.7467654 ],
#        [-1.06806881],
#        [ 0.83765799],
#        [ 0.77990133],
#        [-1.01078865],
#        [ 0.26419114],
#        [ 0.94557896],
#        [ 2.35138384],
#        [-0.88426959],
#        [-0.13766451],
#        [ 1.12112799],
#        [-0.78121828],
#        [-0.6628366 ],
#        [ 0.7385779 ],
#        [ 0.28428794],
#        [ 1.35847848],
#        [ 0.78222709],
#        [ 0.18342881],
#        [-2.10589544],
#        [ 0.20442099],
#        [ 0.00593672],
#        [-0.36725733],
#        [ 0.75947983],
#        [ 0.37771222],
#        [-1.59513748],
#        [-0.61567113],
#        [-1.12779787],
#        [-0.79407322],
#        [ 0.11114592],
#        [-1.3628549 ],
#        [ 0.27467115],
#        [ 0.41867024],
#        [ 0.36135727],
#        [-0.65290391],
#        [ 0.12047752],
#        [-0.12526587],
#        [-1.27573156],
#        [ 0.48021402],
#        [-1.22788392],
#        [-0.11936539],
#        [ 1.79963461],
#        [-0.44782632],
#        [ 0.51483311],
#        [ 0.02415504],
#        [-1.35582389],
#        [ 0.88308016],
#        [-1.79362034],
#        [-0.45449247],
#        [-0.84441837],
#        [ 1.55107723],
#        [ 0.86272697],
#        [ 0.03115227],
#        [ 1.07004824],
#        [ 0.09984218],
#        [-0.85397608],
#        [-1.45434718],
#        [-0.50460467],
#        [ 0.33489919],
#        [-1.78121833],
#        [ 0.19412141],
#        [-0.52760324],
#        [ 2.17340071],
#        [-0.51201356],
#        [-0.37791524],
#        [ 1.11042206],
#        [ 0.41054866],
#        [-0.90228339],
#        [ 1.31470916],
#        [-1.14025402],
#        [-0.10039272],
#        [ 1.61942483],
#        [-0.79020747],
#        [-1.80271711],
#        [-0.04384272],
#        [ 0.45171849],
#        [ 1.31743913],
#        [-0.30154651],
#        [-0.89365426],
#        [-0.25525914],
#        [ 0.35630275],
#        [-0.75178973],
#        [ 0.83536071],
#        [ 0.03994031],
#        [ 0.70652538],
#        [-0.92955935],
#        [-1.88820367],
#        [ 0.36575085],
#        [-0.35844661],
#        [ 1.70202658],
#        [ 1.06700409],
#        [-0.63252216],
#        [-0.72625201]])

# %%
plt.scatter(X,y)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(X,y)
# Out:
# LinearRegression()

# %%
print(lr.intercept_)
# Out:
# 2.7061696674071456

# %%
print(lr.coef_)
# Out:
# [13.58819903]

# %%
class GDRegressor:
    
    def __init__(self,learning_rate, epochs):
        self.m= 13.58819903
        self.b= -120
        self.lr= learning_rate
        self.epochs= epochs
        
    def fit(self,X,y):
        #calculate b using GD
        for i in range(self.epochs):
            loss_slope = -2 * np.sum(y- self.m*X.ravel()- self.b)
            self.b = self.b - (self.lr * loss_slope)
        print(self.b)

# %% [markdown]
# to high for 0.1 and no change for 0.01 in 10 epoch

# %%
gd = GDRegressor(0.001,100)

# %%
gd.fit(X,y)
# Out:
# 2.7061696424688573
