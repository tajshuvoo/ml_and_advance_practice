# %%
from tensorflow import keras
from keras import Sequential
from keras.layers import Dense , SimpleRNN

# %%
model = Sequential()

model.add(SimpleRNN(3,input_shape=(4,5)))
model.add(Dense(1, activation='sigmoid'))

model.summary()
# Out:
# 2025-08-27 17:09:47.799989: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M1 Pro
# 2025-08-27 17:09:47.800120: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 16.00 GB
# 2025-08-27 17:09:47.800142: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 5.33 GB
# 2025-08-27 17:09:47.800473: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2025-08-27 17:09:47.800493: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# /Users/tajbirhasanshuvo/micromamba/envs/tf-m1/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ simple_rnn (SimpleRNN)          │ (None, 3)              │            27 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │             4 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 31 (124.00 B)
#  Trainable params: 31 (124.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
from keras.utils import plot_model

plot_model(model , show_shapes=True)

# %%
model.get_weights()[0].shape
# Out:
# (5, 3)

# %%
model.get_weights()[0]
# Out:
# array([[-0.7620124 , -0.32884324, -0.79721004],
#        [-0.23100924, -0.1036281 , -0.84827644],
#        [-0.5078454 ,  0.18862659,  0.69692105],
#        [ 0.169115  , -0.3639719 , -0.5654839 ],
#        [-0.42295358, -0.43849298,  0.56327456]], dtype=float32)

# %%
model.get_weights()[1].shape
# Out:
# (3, 3)

# %%
model.get_weights()[1]
# Out:
# array([[ 0.26676762, -0.51444364,  0.8149742 ],
#        [-0.90763825,  0.15024781,  0.3919419 ],
#        [ 0.32408005,  0.84425914,  0.42684734]], dtype=float32)

# %%
model.get_weights()[2].shape
# Out:
# (3,)

# %%
model.get_weights()[2]
# Out:
# array([0., 0., 0.], dtype=float32)

# %%
model.get_weights()[3].shape
# Out:
# (3, 1)

# %%
model.get_weights()[3]
# Out:
# array([[1.2149287],
#        [0.9628333],
#        [1.2102138]], dtype=float32)

# %%
model.get_weights()[4].shape
# Out:
# (1,)

# %%
model.get_weights()[4]
# Out:
# array([0.], dtype=float32)
