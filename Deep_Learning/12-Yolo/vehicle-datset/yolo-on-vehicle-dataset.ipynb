# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/vehicle-dataset-for-yolo/vehicle dataset/classes.txt
# /kaggle/input/vehicle-dataset-for-yolo/vehicle dataset/valid/labels/car137.txt
# /kaggle/input/vehicle-dataset-for-yolo/vehicle dataset/valid/labels/2010_005731.txt
# /kaggle/input/vehicle-dataset-for-yolo/vehicle dataset/valid/labels/2087304073_cf836f617b_n.txt
# /kaggle/input/vehicle-dataset-for-yolo/vehicle dataset/valid/labels/94ZMP2S6T3HE.txt
# /kaggle/input/vehicle-dataset-for-yolo/vehicle dataset/valid/labels/srilankamotorbike61.txt
# /kaggle/input/vehicle-dataset-for-yolo/vehicle dataset/valid/labels/2319910999_f35b92a00f_w.txt
# /kaggle/input/vehicle-dataset-for-yolo/vehicle dataset/valid/labels/car318.txt
# /kaggle/input/vehicle-dataset-for-yolo/vehicle dataset/valid/labels/indianvan83.txt
# /kaggle/input/vehicle-dataset-for-yolo/vehicle dataset/valid/labels/srilankamotorbike6.txt
# /kaggle/input/vehicle-dataset-for-yolo/vehicle dataset/valid/labels/2009_003802.txt
# ...

# %%
pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 22.9 MB/s eta 0:00:0000:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.8 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 105.0 MB/s eta 0:00:0000:010:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 77.7 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 44.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.4 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.5 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 31.5 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 13.4 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 2.2 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 77.8 MB/s eta 0:00:00:00:0100:01
# ...

# %%
from ultralytics import YOLO
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
model = YOLO()

model.train(
    data="/kaggle/input/data-for-vehicle/data.yaml",
    epochs=100,
    batch=64,        # try 32 first, adjust if OOM
    imgsz=640,       # standard YOLO size
    workers=2,       # Kaggle often has 2 CPUs per notebook
    device=0         # force GPU
)
# Out:
# ...
# Ultralytics 8.3.192 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla P100-PCIE-16GB, 16269MiB)
# ...

# %%
from ultralytics import YOLO

# load your best weights
model = YOLO("/kaggle/working/runs/detect/train/weights/best.pt")

# run validation
metrics = model.val(data="/kaggle/input/data-for-vehicle/data.yaml")

print(metrics)
# Out:
# Ultralytics 8.3.192 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla P100-PCIE-16GB, 16269MiB)
# YOLO11n summary (fused): 100 layers, 2,583,322 parameters, 0 gradients, 6.3 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 184.0±138.1 MB/s, size: 113.7 KB)
# val: Scanning /kaggle/input/vehicle-dataset-for-yolo/vehicle dataset/valid/labels... 899 images, 0 backgrounds, 1 corrupt: 100% ━━━━━━━━━━━━ 900/900 780.3it/s 1.2s0.0s
# val: /kaggle/input/vehicle-dataset-for-yolo/vehicle dataset/valid/images/car55.jpg: ignoring corrupt image/label: [Errno 30] Read-only file system: '/kaggle/input/vehicle-dataset-for-yolo/vehicle dataset/valid/images/car55.jpg'
# WARNING ⚠️ val: Cache directory /kaggle/input/vehicle-dataset-for-yolo/vehicle dataset/valid is not writeable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 74% ━━━━━━━━╸─── 42/57 11.5it/s 4.5s<1.3s
# libpng warning: iCCP: known incorrect sRGB profile
# ...

# %%
results = model.predict(
    source="/kaggle/input/vehicle-test",
    conf=0.25,
    save=True
)
# Out:
# image 1/7 /kaggle/input/vehicle-test/0x0.webp: 384x640 1 car, 44.2ms
# image 2/7 /kaggle/input/vehicle-test/2018_Ford_Transit_Custom_300_Base_2.0_facelift.jpg: 384x640 1 van, 9.8ms
# image 3/7 /kaggle/input/vehicle-test/Triumph-Rocket-III-motorcycle-2005.webp: 480x640 1 motorbike, 42.1ms
# image 4/7 /kaggle/input/vehicle-test/download (1).jpeg: 384x640 1 car, 8.8ms
# image 5/7 /kaggle/input/vehicle-test/fn_milt-bike_2023_WEB-501.webp: 480x640 1 motorbike, 8.2ms
# image 6/7 /kaggle/input/vehicle-test/rolls-rocyce-cullinan-top_10.jpg: 448x640 1 car, 39.7ms
# image 7/7 /kaggle/input/vehicle-test/van-pages-header-image.png: 352x640 2 vans, 39.8ms
# Speed: 2.0ms preprocess, 27.5ms inference, 1.2ms postprocess per image at shape (1, 3, 352, 640)
# Results saved to runs/detect/predict
