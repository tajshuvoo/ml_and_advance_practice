# %%
from sklearn.datasets import load_diabetes
from sklearn.metrics import r2_score
import numpy as np

# %%
X, y = load_diabetes(return_X_y=True)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=4)

# %%
from sklearn.linear_model import Ridge

# %%
rr = Ridge(alpha=10 ,  solver='cholesky')
rr.fit(X,y)
print(rr.coef_)
print(rr.intercept_)
# Out:
# [ 19.81284181  -0.91842974  75.41621398  55.02515953  19.92462111
#   13.94871542 -47.5538158   48.2594332   70.14394833  44.21389238]
# 152.13348416289594

# %%
y_pred = rr.predict(X_test)

# %%
r2_score(y_test, y_pred)
# Out:
# 0.18312798032156063

# %%
class MyRidge:
    
    def __init__(self, alpha=0.1):
        self.alpha = alpha
        self.coef_ = None
        self.intercept_ = None
        
    def fit(self ,X_train, y_train):
        
        X_train = np.insert(X_train,0,1, axis=1)
        I = np.identity(X_train.shape[1])
        I[0][0] =0
        result = np.linalg.inv(np.dot(X_train.T, X_train) + self.alpha*I ).dot(X_train.T).dot(y_train)
        
        self.intercept_ = result[0]
        self.coef_ = result[1:]
        print(self.intercept_ , self.coef_)
        
    def predict(self, X_test):
        return np.dot(X_test,self.coef_) + self.intercept_

# %%
mridge = MyRidge(alpha=10)
mridge.fit(X,y)
y_pred = mridge.predict(X_test)
# Out:
# 152.13348416289597 [ 19.81284181  -0.91842974  75.41621398  55.02515953  19.92462111
#   13.94871542 -47.5538158   48.2594332   70.14394833  44.21389238]

# %%
r2_score(y_test,y_pred)
# Out:
# 0.18312798032156063
