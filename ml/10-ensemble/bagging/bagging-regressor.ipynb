# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('house.csv',header=1 )

# %%
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  LSTAT  MEDV
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
X = df.drop('MEDV', axis=1).values
y = df['MEDV'].values

# %%
X.shape
# Out:
# (506, 13)

# %%
y.shape
# Out:
# (506,)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import r2_score

# %%
from sklearn.model_selection import train_test_split
x_train , x_test , y_train , y_test = train_test_split(X,y , test_size=0.2, random_state=123)

# %%
lr = LinearRegression()
dt = DecisionTreeRegressor()
knn = KNeighborsRegressor()

# %%
lr.fit(x_train,y_train)
dt.fit(x_train,y_train)
knn.fit(x_train,y_train)
# Out:
# KNeighborsRegressor()

# %%
y_pred1 = lr.predict(x_test)
y_pred2 = dt.predict(x_test)
y_pred3 = knn.predict(x_test)

# %%
print("LR", r2_score(y_test,y_pred1))
print("DT", r2_score(y_test,y_pred2))
print("KNN", r2_score(y_test,y_pred3))
# Out:
# LR 0.6592466510354095
# DT 0.4353568635432771
# KNN 0.5475962186976784

# %%
from sklearn.ensemble import BaggingRegressor

# %%
bag = BaggingRegressor(random_state=1)
bag.fit(x_train,y_train)
# Out:
# BaggingRegressor(random_state=1)

# %%
y_preds = bag.predict(x_test)

# %%
r2_score(y_test,y_preds)
# Out:
# 0.8311446079080576

# %%
params = {
    'estimator':[None, LinearRegression(),DecisionTreeRegressor()],
    'n_estimators': [20,50,100,500],
    'max_samples': [0.7,1],
    'max_features':[0.5,1],
    'bootstrap':[True,False],
    'bootstrap_features':[True,False]
}

bag_grid_srch = GridSearchCV(BaggingRegressor(random_state=1,n_jobs=-1), param_grid=params , cv=5 , n_jobs=-1 , verbose=1)
bag_grid_srch.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 192 candidates, totalling 960 fits
# GridSearchCV(cv=5, estimator=BaggingRegressor(n_jobs=-1, random_state=1),
#              n_jobs=-1,
#              param_grid={'bootstrap': [True, False],
#                          'bootstrap_features': [True, False],
#                          'estimator': [None, LinearRegression(),
#                                        DecisionTreeRegressor()],
#                          'max_features': [0.5, 1], 'max_samples': [0.7, 1],
#                          'n_estimators': [20, 50, 100, 500]},
#              verbose=1)

# %%
print(bag_grid_srch.best_estimator_.score(x_train,y_train))
print(bag_grid_srch.best_estimator_.score(x_test,y_test))
print(bag_grid_srch.best_score_)
# Out:
# 0.9827350517649381
# 0.7984752108532742
# 0.846596979491434

# %%
bag_grid_srch.best_params_
# Out:
# {'bootstrap': False,
#  'bootstrap_features': False,
#  'estimator': None,
#  'max_features': 0.5,
#  'max_samples': 0.7,
#  'n_estimators': 100}
